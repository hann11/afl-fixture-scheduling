# %%
import random
import numpy as np

# %%
teams = ["Adelaide","Brisbane","Carlton","Collingwood","Essendon","Fremantle","Geelong","Gold Coast","GWS",
        "Hawthorn","Melbourne","North Melbourne","Port Adelaide","Richmond","St Kilda","Sydney",
         "West Coast","Western Bulldogs"]

random.shuffle(teams)

# %%
def basic_rr(teams):
    s = {}
    s_per_team = {}
    h_count_per_team = {}
    ha_per_team = {}
    
    #if odd n_teams
    if len(teams) % 2 == 1: 
        teams = teams + [None]
    
    n = len(teams)
    
    for team in teams:
        s_per_team[team] = []
        h_count_per_team[team] = 0
        ha_per_team[team] = []
        
    mid = n//2
    
    for i in range(n-1):
        round=[]
        for j in range(mid):
            t1 = teams[j]
            t2 = teams[n-1-j]
            
            round.append((t1 + " vs. " + t2))
            
            s_per_team[t1].append(t2)
            s_per_team[t2].append(t1)
            h_count_per_team[t1] += 1
            ha_per_team[t1].append("Home")
            ha_per_team[t2].append("Away")
                
        s["Round " + str(i+1)] = round
        
        teams.insert(1,teams.pop())
        
    s_per_team = dict(sorted(s_per_team.items(), key=lambda x: x[0].lower()))
    h_count_per_team = dict(sorted(h_count_per_team.items(), key=lambda x: x[0].lower()))
    ha_per_team = dict(sorted(ha_per_team.items(), key=lambda x: x[0].lower()))
    
    return s, s_per_team, h_count_per_team, ha_per_team

# %%
def round_robin_fair(teams):
    """ Create a schedule for the teams in the list and return it"""
    s = {}
    s_per_team = {}
    h_count_per_team = {}
    ha_per_team = {}
    
    if len(teams) % 2 == 1: teams = teams + [None]
    # manipulate map (array of indexes for list) instead of list itself
    # this takes advantage of even/odd indexes to determine home vs. away
    n = len(teams)
    
    for team in teams:
        s_per_team[team] = []
        h_count_per_team[team] = 0
        ha_per_team[team] = []
        
    map = list(range(n))
    mid = n // 2
    for i in range(n-1):
        l1 = map[:mid]
        l2 = map[mid:]
        l2.reverse()
        #print("Round",i)
        round = []
        
        for j in range(mid):
            t1 = teams[l1[j]]
            t2 = teams[l2[j]]
            if j == 0 and i % 2 == 1:
                # flip the first match only, every other round
                # (this is because the first match always involves the last player in the list)
                round.append((t2,"vs.",t1))
                s_per_team[t2].append(t1)
                s_per_team[t1].append(t2)
                h_count_per_team[t2] += 1
                ha_per_team[t2].append("Home")
                ha_per_team[t1].append("Away")
            else:
                round.append((t1, "vs.", t2))
                s_per_team[t2].append(t1)
                s_per_team[t1].append(t2)
                h_count_per_team[t1] += 1
                ha_per_team[t1].append("Home")
                ha_per_team[t2].append("Away")
                
        s["Round " + str(i+1)] = round
        
        # rotate list by n/2, leaving last element at the end
        map = map[mid:-1] + map[:mid] + map[-1:]
        
    s_per_team = dict(sorted(s_per_team.items(), key=lambda x: x[0].lower()))
    h_count_per_team = dict(sorted(h_count_per_team.items(), key=lambda x: x[0].lower()))
    ha_per_team = dict(sorted(ha_per_team.items(), key=lambda x: x[0].lower()))
    
    return s, s_per_team, h_count_per_team, ha_per_team

# %%
basic_sched, basic_per_team, basic_hcpt, basic_hapt = basic_rr(teams)

# %%
basic_sched
# Out:
# {'Round 1': ['Carlton vs. Gold Coast',
#   'Brisbane vs. Western Bulldogs',
#   'Geelong vs. Sydney',
#   'Hawthorn vs. North Melbourne',
#   'Collingwood vs. Essendon',
#   'Adelaide vs. Port Adelaide',
#   'Melbourne vs. West Coast',
#   'Richmond vs. GWS',
#   'Fremantle vs. St Kilda'],
#  'Round 2': ['Carlton vs. Western Bulldogs',
#   'Gold Coast vs. Sydney',
#   'Brisbane vs. North Melbourne',
#   'Geelong vs. Essendon',
#   'Hawthorn vs. Port Adelaide',
#   'Collingwood vs. West Coast',
#   'Adelaide vs. GWS',
#   'Melbourne vs. St Kilda',
#   'Richmond vs. Fremantle'],
#  'Round 3': ['Carlton vs. Sydney',
#   'Western Bulldogs vs. North Melbourne',
#   'Gold Coast vs. Essendon',
#   'Brisbane vs. Port Adelaide',
#   'Geelong vs. West Coast',
#   'Hawthorn vs. GWS',
#   'Collingwood vs. St Kilda',
#   'Adelaide vs. Fremantle',
#   'Melbourne vs. Richmond'],
#  'Round 4': ['Carlton vs. North Melbourne',
#   'Sydney vs. Essendon',
#   'Western Bulldogs vs. Port Adelaide',
#   'Gold Coast vs. West Coast',
#   'Brisbane vs. GWS',
#   'Geelong vs. St Kilda',
#   'Hawthorn vs. Fremantle',
#   'Collingwood vs. Richmond',
#   'Adelaide vs. Melbourne'],
#  'Round 5': ['Carlton vs. Essendon',
#   'North Melbourne vs. Port Adelaide',
#   'Sydney vs. West Coast',
#   'Western Bulldogs vs. GWS',
#   'Gold Coast vs. St Kilda',
#   'Brisbane vs. Fremantle',
#   'Geelong vs. Richmond',
#   'Hawthorn vs. Melbourne',
#   'Collingwood vs. Adelaide'],
#  'Round 6': ['Carlton vs. Port Adelaide',
#   'Essendon vs. West Coast',
#   'North Melbourne vs. GWS',
#   'Sydney vs. St Kilda',
#   'Western Bulldogs vs. Fremantle',
#   'Gold Coast vs. Richmond',
#   'Brisbane vs. Melbourne',
#   'Geelong vs. Adelaide',
#   'Hawthorn vs. Collingwood'],
#  'Round 7': ['Carlton vs. West Coast',
#   'Port Adelaide vs. GWS',
#   'Essendon vs. St Kilda',
#   'North Melbourne vs. Fremantle',
#   'Sydney vs. Richmond',
#   'Western Bulldogs vs. Melbourne',
#   'Gold Coast vs. Adelaide',
#   'Brisbane vs. Collingwood',
#   'Geelong vs. Hawthorn'],
#  'Round 8': ['Carlton vs. GWS',
#   'West Coast vs. St Kilda',
#   'Port Adelaide vs. Fremantle',
#   'Essendon vs. Richmond',
#   'North Melbourne vs. Melbourne',
#   'Sydney vs. Adelaide',
#   'Western Bulldogs vs. Collingwood',
#   'Gold Coast vs. Hawthorn',
#   'Brisbane vs. Geelong'],
#  'Round 9': ['Carlton vs. St Kilda',
#   'GWS vs. Fremantle',
#   'West Coast vs. Richmond',
#   'Port Adelaide vs. Melbourne',
#   'Essendon vs. Adelaide',
#   'North Melbourne vs. Collingwood',
#   'Sydney vs. Hawthorn',
#   'Western Bulldogs vs. Geelong',
#   'Gold Coast vs. Brisbane'],
#  'Round 10': ['Carlton vs. Fremantle',
#   'St Kilda vs. Richmond',
#   'GWS vs. Melbourne',
#   'West Coast vs. Adelaide',
#   'Port Adelaide vs. Collingwood',
#   'Essendon vs. Hawthorn',
#   'North Melbourne vs. Geelong',
#   'Sydney vs. Brisbane',
#   'Western Bulldogs vs. Gold Coast'],
#  'Round 11': ['Carlton vs. Richmond',
#   'Fremantle vs. Melbourne',
#   'St Kilda vs. Adelaide',
#   'GWS vs. Collingwood',
#   'West Coast vs. Hawthorn',
#   'Port Adelaide vs. Geelong',
#   'Essendon vs. Brisbane',
#   'North Melbourne vs. Gold Coast',
#   'Sydney vs. Western Bulldogs'],
#  'Round 12': ['Carlton vs. Melbourne',
#   'Richmond vs. Adelaide',
#   'Fremantle vs. Collingwood',
#   'St Kilda vs. Hawthorn',
#   'GWS vs. Geelong',
#   'West Coast vs. Brisbane',
#   'Port Adelaide vs. Gold Coast',
#   'Essendon vs. Western Bulldogs',
#   'North Melbourne vs. Sydney'],
#  'Round 13': ['Carlton vs. Adelaide',
#   'Melbourne vs. Collingwood',
#   'Richmond vs. Hawthorn',
#   'Fremantle vs. Geelong',
#   'St Kilda vs. Brisbane',
#   'GWS vs. Gold Coast',
#   'West Coast vs. Western Bulldogs',
#   'Port Adelaide vs. Sydney',
#   'Essendon vs. North Melbourne'],
#  'Round 14': ['Carlton vs. Collingwood',
#   'Adelaide vs. Hawthorn',
#   'Melbourne vs. Geelong',
#   'Richmond vs. Brisbane',
#   'Fremantle vs. Gold Coast',
#   'St Kilda vs. Western Bulldogs',
#   'GWS vs. Sydney',
#   'West Coast vs. North Melbourne',
#   'Port Adelaide vs. Essendon'],
#  'Round 15': ['Carlton vs. Hawthorn',
#   'Collingwood vs. Geelong',
#   'Adelaide vs. Brisbane',
#   'Melbourne vs. Gold Coast',
#   'Richmond vs. Western Bulldogs',
#   'Fremantle vs. Sydney',
#   'St Kilda vs. North Melbourne',
#   'GWS vs. Essendon',
#   'West Coast vs. Port Adelaide'],
#  'Round 16': ['Carlton vs. Geelong',
#   'Hawthorn vs. Brisbane',
#   'Collingwood vs. Gold Coast',
#   'Adelaide vs. Western Bulldogs',
#   'Melbourne vs. Sydney',
#   'Richmond vs. North Melbourne',
#   'Fremantle vs. Essendon',
#   'St Kilda vs. Port Adelaide',
#   'GWS vs. West Coast'],
#  'Round 17': ['Carlton vs. Brisbane',
#   'Geelong vs. Gold Coast',
#   'Hawthorn vs. Western Bulldogs',
#   'Collingwood vs. Sydney',
#   'Adelaide vs. North Melbourne',
#   'Melbourne vs. Essendon',
#   'Richmond vs. Port Adelaide',
#   'Fremantle vs. West Coast',
#   'St Kilda vs. GWS']}

# %%
basic_hapt
#note no HA-fair recurrence, lots of home and away games in a row, first team is biased all home
# Out:
# {'Adelaide': ['Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home'],
#  'Brisbane': ['Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away'],
#  'Carlton': ['Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home'],
#  'Collingwood': ['Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home'],
#  'Essendon': ['Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away'],
#  'Fremantle': ['Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home'],
#  'Geelong': ['Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home'],
#  'Gold Coast': ['Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away'],
#  'GWS': ['Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away'],
#  'Hawthorn': ['Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home'],
#  'Melbourne': ['Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home'],
#  'North Melbourne': ['Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away'],
#  'Port Adelaide': ['Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away'],
#  'Richmond': ['Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home'],
#  'St Kilda': ['Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home'],
#  'Sydney': ['Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away'],
#  'West Coast': ['Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away'],
#  'Western Bulldogs': ['Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away']}

# %%
sched, per_team, hcpt, hapt = round_robin_fair(teams)

# %%
sched
# Out:
# {'Round 1': [('Carlton', 'vs.', 'Gold Coast'),
#   ('Brisbane', 'vs.', 'Western Bulldogs'),
#   ('Geelong', 'vs.', 'Sydney'),
#   ('Hawthorn', 'vs.', 'North Melbourne'),
#   ('Collingwood', 'vs.', 'Essendon'),
#   ('Adelaide', 'vs.', 'Port Adelaide'),
#   ('Melbourne', 'vs.', 'West Coast'),
#   ('Richmond', 'vs.', 'GWS'),
#   ('Fremantle', 'vs.', 'St Kilda')],
#  'Round 2': [('Gold Coast', 'vs.', 'St Kilda'),
#   ('GWS', 'vs.', 'Fremantle'),
#   ('West Coast', 'vs.', 'Richmond'),
#   ('Port Adelaide', 'vs.', 'Melbourne'),
#   ('Essendon', 'vs.', 'Adelaide'),
#   ('North Melbourne', 'vs.', 'Collingwood'),
#   ('Sydney', 'vs.', 'Hawthorn'),
#   ('Western Bulldogs', 'vs.', 'Geelong'),
#   ('Carlton', 'vs.', 'Brisbane')],
#  'Round 3': [('Brisbane', 'vs.', 'Gold Coast'),
#   ('Geelong', 'vs.', 'Carlton'),
#   ('Hawthorn', 'vs.', 'Western Bulldogs'),
#   ('Collingwood', 'vs.', 'Sydney'),
#   ('Adelaide', 'vs.', 'North Melbourne'),
#   ('Melbourne', 'vs.', 'Essendon'),
#   ('Richmond', 'vs.', 'Port Adelaide'),
#   ('Fremantle', 'vs.', 'West Coast'),
#   ('St Kilda', 'vs.', 'GWS')],
#  'Round 4': [('Gold Coast', 'vs.', 'GWS'),
#   ('West Coast', 'vs.', 'St Kilda'),
#   ('Port Adelaide', 'vs.', 'Fremantle'),
#   ('Essendon', 'vs.', 'Richmond'),
#   ('North Melbourne', 'vs.', 'Melbourne'),
#   ('Sydney', 'vs.', 'Adelaide'),
#   ('Western Bulldogs', 'vs.', 'Collingwood'),
#   ('Carlton', 'vs.', 'Hawthorn'),
#   ('Brisbane', 'vs.', 'Geelong')],
#  'Round 5': [('Geelong', 'vs.', 'Gold Coast'),
#   ('Hawthorn', 'vs.', 'Brisbane'),
#   ('Collingwood', 'vs.', 'Carlton'),
#   ('Adelaide', 'vs.', 'Western Bulldogs'),
#   ('Melbourne', 'vs.', 'Sydney'),
#   ('Richmond', 'vs.', 'North Melbourne'),
#   ('Fremantle', 'vs.', 'Essendon'),
#   ('St Kilda', 'vs.', 'Port Adelaide'),
#   ('GWS', 'vs.', 'West Coast')],
#  'Round 6': [('Gold Coast', 'vs.', 'West Coast'),
#   ('Port Adelaide', 'vs.', 'GWS'),
#   ('Essendon', 'vs.', 'St Kilda'),
#   ('North Melbourne', 'vs.', 'Fremantle'),
#   ('Sydney', 'vs.', 'Richmond'),
#   ('Western Bulldogs', 'vs.', 'Melbourne'),
#   ('Carlton', 'vs.', 'Adelaide'),
#   ('Brisbane', 'vs.', 'Collingwood'),
#   ('Geelong', 'vs.', 'Hawthorn')],
#  'Round 7': [('Hawthorn', 'vs.', 'Gold Coast'),
#   ('Collingwood', 'vs.', 'Geelong'),
#   ('Adelaide', 'vs.', 'Brisbane'),
#   ('Melbourne', 'vs.', 'Carlton'),
#   ('Richmond', 'vs.', 'Western Bulldogs'),
#   ('Fremantle', 'vs.', 'Sydney'),
#   ('St Kilda', 'vs.', 'North Melbourne'),
#   ('GWS', 'vs.', 'Essendon'),
#   ('West Coast', 'vs.', 'Port Adelaide')],
#  'Round 8': [('Gold Coast', 'vs.', 'Port Adelaide'),
#   ('Essendon', 'vs.', 'West Coast'),
#   ('North Melbourne', 'vs.', 'GWS'),
#   ('Sydney', 'vs.', 'St Kilda'),
#   ('Western Bulldogs', 'vs.', 'Fremantle'),
#   ('Carlton', 'vs.', 'Richmond'),
#   ('Brisbane', 'vs.', 'Melbourne'),
#   ('Geelong', 'vs.', 'Adelaide'),
#   ('Hawthorn', 'vs.', 'Collingwood')],
#  'Round 9': [('Collingwood', 'vs.', 'Gold Coast'),
#   ('Adelaide', 'vs.', 'Hawthorn'),
#   ('Melbourne', 'vs.', 'Geelong'),
#   ('Richmond', 'vs.', 'Brisbane'),
#   ('Fremantle', 'vs.', 'Carlton'),
#   ('St Kilda', 'vs.', 'Western Bulldogs'),
#   ('GWS', 'vs.', 'Sydney'),
#   ('West Coast', 'vs.', 'North Melbourne'),
#   ('Port Adelaide', 'vs.', 'Essendon')],
#  'Round 10': [('Gold Coast', 'vs.', 'Essendon'),
#   ('North Melbourne', 'vs.', 'Port Adelaide'),
#   ('Sydney', 'vs.', 'West Coast'),
#   ('Western Bulldogs', 'vs.', 'GWS'),
#   ('Carlton', 'vs.', 'St Kilda'),
#   ('Brisbane', 'vs.', 'Fremantle'),
#   ('Geelong', 'vs.', 'Richmond'),
#   ('Hawthorn', 'vs.', 'Melbourne'),
#   ('Collingwood', 'vs.', 'Adelaide')],
#  'Round 11': [('Adelaide', 'vs.', 'Gold Coast'),
#   ('Melbourne', 'vs.', 'Collingwood'),
#   ('Richmond', 'vs.', 'Hawthorn'),
#   ('Fremantle', 'vs.', 'Geelong'),
#   ('St Kilda', 'vs.', 'Brisbane'),
#   ('GWS', 'vs.', 'Carlton'),
#   ('West Coast', 'vs.', 'Western Bulldogs'),
#   ('Port Adelaide', 'vs.', 'Sydney'),
#   ('Essendon', 'vs.', 'North Melbourne')],
#  'Round 12': [('Gold Coast', 'vs.', 'North Melbourne'),
#   ('Sydney', 'vs.', 'Essendon'),
#   ('Western Bulldogs', 'vs.', 'Port Adelaide'),
#   ('Carlton', 'vs.', 'West Coast'),
#   ('Brisbane', 'vs.', 'GWS'),
#   ('Geelong', 'vs.', 'St Kilda'),
#   ('Hawthorn', 'vs.', 'Fremantle'),
#   ('Collingwood', 'vs.', 'Richmond'),
#   ('Adelaide', 'vs.', 'Melbourne')],
#  'Round 13': [('Melbourne', 'vs.', 'Gold Coast'),
#   ('Richmond', 'vs.', 'Adelaide'),
#   ('Fremantle', 'vs.', 'Collingwood'),
#   ('St Kilda', 'vs.', 'Hawthorn'),
#   ('GWS', 'vs.', 'Geelong'),
#   ('West Coast', 'vs.', 'Brisbane'),
#   ('Port Adelaide', 'vs.', 'Carlton'),
#   ('Essendon', 'vs.', 'Western Bulldogs'),
#   ('North Melbourne', 'vs.', 'Sydney')],
#  'Round 14': [('Gold Coast', 'vs.', 'Sydney'),
#   ('Western Bulldogs', 'vs.', 'North Melbourne'),
#   ('Carlton', 'vs.', 'Essendon'),
#   ('Brisbane', 'vs.', 'Port Adelaide'),
#   ('Geelong', 'vs.', 'West Coast'),
#   ('Hawthorn', 'vs.', 'GWS'),
#   ('Collingwood', 'vs.', 'St Kilda'),
#   ('Adelaide', 'vs.', 'Fremantle'),
#   ('Melbourne', 'vs.', 'Richmond')],
#  'Round 15': [('Richmond', 'vs.', 'Gold Coast'),
#   ('Fremantle', 'vs.', 'Melbourne'),
#   ('St Kilda', 'vs.', 'Adelaide'),
#   ('GWS', 'vs.', 'Collingwood'),
#   ('West Coast', 'vs.', 'Hawthorn'),
#   ('Port Adelaide', 'vs.', 'Geelong'),
#   ('Essendon', 'vs.', 'Brisbane'),
#   ('North Melbourne', 'vs.', 'Carlton'),
#   ('Sydney', 'vs.', 'Western Bulldogs')],
#  'Round 16': [('Gold Coast', 'vs.', 'Western Bulldogs'),
#   ('Carlton', 'vs.', 'Sydney'),
#   ('Brisbane', 'vs.', 'North Melbourne'),
#   ('Geelong', 'vs.', 'Essendon'),
#   ('Hawthorn', 'vs.', 'Port Adelaide'),
#   ('Collingwood', 'vs.', 'West Coast'),
#   ('Adelaide', 'vs.', 'GWS'),
#   ('Melbourne', 'vs.', 'St Kilda'),
#   ('Richmond', 'vs.', 'Fremantle')],
#  'Round 17': [('Fremantle', 'vs.', 'Gold Coast'),
#   ('St Kilda', 'vs.', 'Richmond'),
#   ('GWS', 'vs.', 'Melbourne'),
#   ('West Coast', 'vs.', 'Adelaide'),
#   ('Port Adelaide', 'vs.', 'Collingwood'),
#   ('Essendon', 'vs.', 'Hawthorn'),
#   ('North Melbourne', 'vs.', 'Geelong'),
#   ('Sydney', 'vs.', 'Brisbane'),
#   ('Western Bulldogs', 'vs.', 'Carlton')]}

# %%
hapt
# Out:
# {'Adelaide': ['Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away'],
#  'Brisbane': ['Home',
#   'Away',
#   'Home',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away'],
#  'Carlton': ['Home',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away'],
#  'Collingwood': ['Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away'],
#  'Essendon': ['Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home'],
#  'Fremantle': ['Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home'],
#  'Geelong': ['Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away'],
#  'Gold Coast': ['Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away'],
#  'GWS': ['Away',
#   'Home',
#   'Away',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home'],
#  'Hawthorn': ['Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away'],
#  'Melbourne': ['Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Home',
#   'Away',
#   'Home',
#   'Away'],
#  'North Melbourne': ['Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home'],
#  'Port Adelaide': ['Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home'],
#  'Richmond': ['Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Home',
#   'Away'],
#  'St Kilda': ['Away',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home'],
#  'Sydney': ['Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Away',
#   'Home',
#   'Away',
#   'Home'],
#  'West Coast': ['Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home'],
#  'Western Bulldogs': ['Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Away',
#   'Home']}

# %%
team_rankings = {}

#based on 2021 ladder position
team_rankings["Adelaide"]=15
team_rankings["Brisbane"]=4
team_rankings["Carlton"]=13
team_rankings["Collingwood"]=17
team_rankings["Essendon"]=8
team_rankings["Fremantle"]=11
team_rankings["Geelong"]=3
team_rankings["Gold Coast"]=16
team_rankings["GWS"]=7
team_rankings["Hawthorn"]=14
team_rankings["Melbourne"]=1
team_rankings["North Melbourne"]=18
team_rankings["Port Adelaide"]=2
team_rankings["Richmond"]=12
team_rankings["St Kilda"]=10
team_rankings["Sydney"]=6
team_rankings["West Coast"]=9
team_rankings["Western Bulldogs"]=5

# %%
team_grounds = {}

team_grounds["Adelaide"]="Adelaide Oval"
team_grounds["Brisbane"]="Gabba"
team_grounds["Carlton"]="MCG"
team_grounds["Collingwood"]="MCG"
team_grounds["Essendon"]="MCG"
team_grounds["Fremantle"]="Optus Stadium"
team_grounds["Geelong"]="GMHBA Stadium"
team_grounds["Gold Coast"]="Metricon Stadium"
team_grounds["GWS"]="GIANTS Stadium"
team_grounds["Hawthorn"]="MCG"
team_grounds["Melbourne"]="MCG"
team_grounds["North Melbourne"]="Marvel Stadium"
team_grounds["Port Adelaide"]="Adelaide Oval"
team_grounds["Richmond"]="MCG"
team_grounds["St Kilda"]="Marvel Stadium"
team_grounds["Sydney"]="SCG"
team_grounds["West Coast"]="Optus Stadium"
team_grounds["Western Bulldogs"]="Marvel Stadium"

# %%
timeslots = {}

timeslots[1] = 'Thursday 7.50pm'
timeslots[2] = 'Friday 7.50pm'
timeslots[3] = 'Saturday 7.25pm'
timeslots[4] = 'Saturday 7.40pm'
timeslots[5] = 'Saturday 2.10pm'
timeslots[6] = 'Saturday 1.45pm'
timeslots[7] = 'Sunday 3.20pm'
timeslots[8] = 'Sunday 1.10pm'
timeslots[9] = 'Sunday 4.40pm'

# %%
def optimize_tv_ratings(schedule):
    
    new_schedule = {}
    new_schedule_chron = {}
    
    for round in schedule:
        temp_rating_list = []
        for game in schedule[round]:
            hometeam = game[0]
            awayteam = game[2]
            
            htr = team_rankings[hometeam]
            atr = team_rankings[awayteam]
            
            temp_rating_list.append(htr+atr)
        
        
        argsort_trl = np.argsort(temp_rating_list)
        
        newround=[]
        
        for i in range(len(temp_rating_list)):
            nextgame = argsort_trl[i]
            
            hometeam = sched[round][nextgame][0]
            awayteam = sched[round][nextgame][2]
            
            ground = team_grounds[hometeam]
            
            timeslot = timeslots[i+1]
            
            newround.append([(hometeam + " vs. " + awayteam +  " at " + ground + ", " + timeslot + ". Score = " + str(temp_rating_list[nextgame]))])
            
        new_schedule[round]=newround
    
    
    #ensure games are chronological
    
    for round in new_schedule:
        
        chronround = []
        
        chronround.append(new_schedule[round][0])
        chronround.append(new_schedule[round][1])
        chronround.append(new_schedule[round][5])
        chronround.append(new_schedule[round][4])
        chronround.append(new_schedule[round][2])
        chronround.append(new_schedule[round][3])
        chronround.append(new_schedule[round][7])
        chronround.append(new_schedule[round][6])
        chronround.append(new_schedule[round][8])
        
    
        new_schedule_chron[round]=chronround
        
        
    return new_schedule_chron

# %%
newsched = optimize_tv_ratings(sched)

# %%
newsched
# Out:
# {'Round 1': [['Brisbane vs. Western Bulldogs at Gabba, Thursday 7.50pm. Score = 9'],
#   ['Geelong vs. Sydney at GMHBA Stadium, Friday 7.50pm. Score = 9'],
#   ['Fremantle vs. St Kilda at Optus Stadium, Saturday 1.45pm. Score = 21'],
#   ['Richmond vs. GWS at MCG, Saturday 2.10pm. Score = 19'],
#   ['Melbourne vs. West Coast at MCG, Saturday 7.25pm. Score = 10'],
#   ['Adelaide vs. Port Adelaide at Adelaide Oval, Saturday 7.40pm. Score = 17'],
#   ['Carlton vs. Gold Coast at MCG, Sunday 1.10pm. Score = 29'],
#   ['Collingwood vs. Essendon at MCG, Sunday 3.20pm. Score = 25'],
#   ['Hawthorn vs. North Melbourne at MCG, Sunday 4.40pm. Score = 32']],
#  'Round 2': [['Port Adelaide vs. Melbourne at Adelaide Oval, Thursday 7.50pm. Score = 3'],
#   ['Western Bulldogs vs. Geelong at Marvel Stadium, Friday 7.50pm. Score = 8'],
#   ['West Coast vs. Richmond at Optus Stadium, Saturday 1.45pm. Score = 21'],
#   ['Sydney vs. Hawthorn at SCG, Saturday 2.10pm. Score = 20'],
#   ['Carlton vs. Brisbane at MCG, Saturday 7.25pm. Score = 17'],
#   ['GWS vs. Fremantle at GIANTS Stadium, Saturday 7.40pm. Score = 18'],
#   ['Gold Coast vs. St Kilda at Metricon Stadium, Sunday 1.10pm. Score = 26'],
#   ['Essendon vs. Adelaide at MCG, Sunday 3.20pm. Score = 23'],
#   ['North Melbourne vs. Collingwood at Marvel Stadium, Sunday 4.40pm. Score = 35']],
#  'Round 3': [['Melbourne vs. Essendon at MCG, Thursday 7.50pm. Score = 9'],
#   ['Richmond vs. Port Adelaide at MCG, Friday 7.50pm. Score = 14'],
#   ['Brisbane vs. Gold Coast at Gabba, Saturday 1.45pm. Score = 20'],
#   ['Hawthorn vs. Western Bulldogs at MCG, Saturday 2.10pm. Score = 19'],
#   ['Geelong vs. Carlton at GMHBA Stadium, Saturday 7.25pm. Score = 16'],
#   ['St Kilda vs. GWS at Marvel Stadium, Saturday 7.40pm. Score = 17'],
#   ['Collingwood vs. Sydney at MCG, Sunday 1.10pm. Score = 23'],
#   ['Fremantle vs. West Coast at Optus Stadium, Sunday 3.20pm. Score = 20'],
#   ['Adelaide vs. North Melbourne at Adelaide Oval, Sunday 4.40pm. Score = 33']],
#  'Round 4': [['Brisbane vs. Geelong at Gabba, Thursday 7.50pm. Score = 7'],
#   ['Port Adelaide vs. Fremantle at Adelaide Oval, Friday 7.50pm. Score = 13'],
#   ['Sydney vs. Adelaide at SCG, Saturday 1.45pm. Score = 21'],
#   ['Essendon vs. Richmond at MCG, Saturday 2.10pm. Score = 20'],
#   ['West Coast vs. St Kilda at Optus Stadium, Saturday 7.25pm. Score = 19'],
#   ['North Melbourne vs. Melbourne at Marvel Stadium, Saturday 7.40pm. Score = 19'],
#   ['Gold Coast vs. GWS at Metricon Stadium, Sunday 1.10pm. Score = 23'],
#   ['Western Bulldogs vs. Collingwood at Marvel Stadium, Sunday 3.20pm. Score = 22'],
#   ['Carlton vs. Hawthorn at MCG, Sunday 4.40pm. Score = 27']],
#  'Round 5': [['Melbourne vs. Sydney at MCG, Thursday 7.50pm. Score = 7'],
#   ['St Kilda vs. Port Adelaide at Marvel Stadium, Friday 7.50pm. Score = 12'],
#   ['Fremantle vs. Essendon at Optus Stadium, Saturday 1.45pm. Score = 19'],
#   ['Geelong vs. Gold Coast at GMHBA Stadium, Saturday 2.10pm. Score = 19'],
#   ['GWS vs. West Coast at GIANTS Stadium, Saturday 7.25pm. Score = 16'],
#   ['Hawthorn vs. Brisbane at MCG, Saturday 7.40pm. Score = 18'],
#   ['Collingwood vs. Carlton at MCG, Sunday 1.10pm. Score = 30'],
#   ['Adelaide vs. Western Bulldogs at Adelaide Oval, Sunday 3.20pm. Score = 20'],
#   ['Richmond vs. North Melbourne at MCG, Sunday 4.40pm. Score = 30']],
#  'Round 6': [['Western Bulldogs vs. Melbourne at Marvel Stadium, Thursday 7.50pm. Score = 6'],
#   ['Port Adelaide vs. GWS at Adelaide Oval, Friday 7.50pm. Score = 9'],
#   ['Brisbane vs. Collingwood at Gabba, Saturday 1.45pm. Score = 21'],
#   ['Sydney vs. Richmond at SCG, Saturday 2.10pm. Score = 18'],
#   ['Geelong vs. Hawthorn at GMHBA Stadium, Saturday 7.25pm. Score = 17'],
#   ['Essendon vs. St Kilda at MCG, Saturday 7.40pm. Score = 18'],
#   ['Carlton vs. Adelaide at MCG, Sunday 1.10pm. Score = 28'],
#   ['Gold Coast vs. West Coast at Metricon Stadium, Sunday 3.20pm. Score = 25'],
#   ['North Melbourne vs. Fremantle at Marvel Stadium, Sunday 4.40pm. Score = 29']],
#  'Round 7': [['West Coast vs. Port Adelaide at Optus Stadium, Thursday 7.50pm. Score = 11'],
#   ['Melbourne vs. Carlton at MCG, Friday 7.50pm. Score = 14'],
#   ['Adelaide vs. Brisbane at Adelaide Oval, Saturday 1.45pm. Score = 19'],
#   ['Fremantle vs. Sydney at Optus Stadium, Saturday 2.10pm. Score = 17'],
#   ['GWS vs. Essendon at GIANTS Stadium, Saturday 7.25pm. Score = 15'],
#   ['Richmond vs. Western Bulldogs at MCG, Saturday 7.40pm. Score = 17'],
#   ['St Kilda vs. North Melbourne at Marvel Stadium, Sunday 1.10pm. Score = 28'],
#   ['Collingwood vs. Geelong at MCG, Sunday 3.20pm. Score = 20'],
#   ['Hawthorn vs. Gold Coast at MCG, Sunday 4.40pm. Score = 30']],
#  'Round 8': [['Brisbane vs. Melbourne at Gabba, Thursday 7.50pm. Score = 5'],
#   ['Sydney vs. St Kilda at SCG, Friday 7.50pm. Score = 16'],
#   ['Geelong vs. Adelaide at GMHBA Stadium, Saturday 1.45pm. Score = 18'],
#   ['Gold Coast vs. Port Adelaide at Metricon Stadium, Saturday 2.10pm. Score = 18'],
#   ['Western Bulldogs vs. Fremantle at Marvel Stadium, Saturday 7.25pm. Score = 16'],
#   ['Essendon vs. West Coast at MCG, Saturday 7.40pm. Score = 17'],
#   ['Carlton vs. Richmond at MCG, Sunday 1.10pm. Score = 25'],
#   ['North Melbourne vs. GWS at Marvel Stadium, Sunday 3.20pm. Score = 25'],
#   ['Hawthorn vs. Collingwood at MCG, Sunday 4.40pm. Score = 31']],
#  'Round 9': [['Melbourne vs. Geelong at MCG, Thursday 7.50pm. Score = 4'],
#   ['Port Adelaide vs. Essendon at Adelaide Oval, Friday 7.50pm. Score = 10'],
#   ['Fremantle vs. Carlton at Optus Stadium, Saturday 1.45pm. Score = 24'],
#   ['Richmond vs. Brisbane at MCG, Saturday 2.10pm. Score = 16'],
#   ['GWS vs. Sydney at GIANTS Stadium, Saturday 7.25pm. Score = 13'],
#   ['St Kilda vs. Western Bulldogs at Marvel Stadium, Saturday 7.40pm. Score = 15'],
#   ['Adelaide vs. Hawthorn at Adelaide Oval, Sunday 1.10pm. Score = 29'],
#   ['West Coast vs. North Melbourne at Optus Stadium, Sunday 3.20pm. Score = 27'],
#   ['Collingwood vs. Gold Coast at MCG, Sunday 4.40pm. Score = 33']],
#  'Round 10': [['Western Bulldogs vs. GWS at Marvel Stadium, Thursday 7.50pm. Score = 12'],
#   ['Sydney vs. West Coast at SCG, Friday 7.50pm. Score = 15'],
#   ['North Melbourne vs. Port Adelaide at Marvel Stadium, Saturday 1.45pm. Score = 20'],
#   ['Hawthorn vs. Melbourne at MCG, Saturday 2.10pm. Score = 15'],
#   ['Brisbane vs. Fremantle at Gabba, Saturday 7.25pm. Score = 15'],
#   ['Geelong vs. Richmond at GMHBA Stadium, Saturday 7.40pm. Score = 15'],
#   ['Gold Coast vs. Essendon at Metricon Stadium, Sunday 1.10pm. Score = 24'],
#   ['Carlton vs. St Kilda at MCG, Sunday 3.20pm. Score = 23'],
#   ['Collingwood vs. Adelaide at MCG, Sunday 4.40pm. Score = 32']],
#  'Round 11': [['Port Adelaide vs. Sydney at Adelaide Oval, Thursday 7.50pm. Score = 8'],
#   ['Fremantle vs. Geelong at Optus Stadium, Friday 7.50pm. Score = 14'],
#   ['GWS vs. Carlton at GIANTS Stadium, Saturday 1.45pm. Score = 20'],
#   ['Melbourne vs. Collingwood at MCG, Saturday 2.10pm. Score = 18'],
#   ['St Kilda vs. Brisbane at Marvel Stadium, Saturday 7.25pm. Score = 14'],
#   ['West Coast vs. Western Bulldogs at Optus Stadium, Saturday 7.40pm. Score = 14'],
#   ['Essendon vs. North Melbourne at MCG, Sunday 1.10pm. Score = 26'],
#   ['Richmond vs. Hawthorn at MCG, Sunday 3.20pm. Score = 26'],
#   ['Adelaide vs. Gold Coast at Adelaide Oval, Sunday 4.40pm. Score = 31']],
#  'Round 12': [['Western Bulldogs vs. Port Adelaide at Marvel Stadium, Thursday 7.50pm. Score = 7'],
#   ['Brisbane vs. GWS at Gabba, Friday 7.50pm. Score = 11'],
#   ['Carlton vs. West Coast at MCG, Saturday 1.45pm. Score = 22'],
#   ['Adelaide vs. Melbourne at Adelaide Oval, Saturday 2.10pm. Score = 16'],
#   ['Geelong vs. St Kilda at GMHBA Stadium, Saturday 7.25pm. Score = 13'],
#   ['Sydney vs. Essendon at SCG, Saturday 7.40pm. Score = 14'],
#   ['Collingwood vs. Richmond at MCG, Sunday 1.10pm. Score = 29'],
#   ['Hawthorn vs. Fremantle at MCG, Sunday 3.20pm. Score = 25'],
#   ['Gold Coast vs. North Melbourne at Metricon Stadium, Sunday 4.40pm. Score = 34']],
#  'Round 13': [['GWS vs. Geelong at GIANTS Stadium, Thursday 7.50pm. Score = 10'],
#   ['West Coast vs. Brisbane at Optus Stadium, Friday 7.50pm. Score = 13'],
#   ['St Kilda vs. Hawthorn at Marvel Stadium, Saturday 1.45pm. Score = 24'],
#   ['Melbourne vs. Gold Coast at MCG, Saturday 2.10pm. Score = 17'],
#   ['Essendon vs. Western Bulldogs at MCG, Saturday 7.25pm. Score = 13'],
#   ['Port Adelaide vs. Carlton at Adelaide Oval, Saturday 7.40pm. Score = 15'],
#   ['Richmond vs. Adelaide at MCG, Sunday 1.10pm. Score = 27'],
#   ['North Melbourne vs. Sydney at Marvel Stadium, Sunday 3.20pm. Score = 24'],
#   ['Fremantle vs. Collingwood at Optus Stadium, Sunday 4.40pm. Score = 28']],
#  'Round 14': [['Brisbane vs. Port Adelaide at Gabba, Thursday 7.50pm. Score = 6'],
#   ['Geelong vs. West Coast at GMHBA Stadium, Friday 7.50pm. Score = 12'],
#   ['Gold Coast vs. Sydney at Metricon Stadium, Saturday 1.45pm. Score = 22'],
#   ['Hawthorn vs. GWS at MCG, Saturday 2.10pm. Score = 21'],
#   ['Melbourne vs. Richmond at MCG, Saturday 7.25pm. Score = 13'],
#   ['Carlton vs. Essendon at MCG, Saturday 7.40pm. Score = 21'],
#   ['Adelaide vs. Fremantle at Adelaide Oval, Sunday 1.10pm. Score = 26'],
#   ['Western Bulldogs vs. North Melbourne at Marvel Stadium, Sunday 3.20pm. Score = 23'],
#   ['Collingwood vs. St Kilda at MCG, Sunday 4.40pm. Score = 27']],
#  'Round 15': [['Port Adelaide vs. Geelong at Adelaide Oval, Thursday 7.50pm. Score = 5'],
#   ['Sydney vs. Western Bulldogs at SCG, Friday 7.50pm. Score = 11'],
#   ['GWS vs. Collingwood at GIANTS Stadium, Saturday 1.45pm. Score = 24'],
#   ['West Coast vs. Hawthorn at Optus Stadium, Saturday 2.10pm. Score = 23'],
#   ['Fremantle vs. Melbourne at Optus Stadium, Saturday 7.25pm. Score = 12'],
#   ['Essendon vs. Brisbane at MCG, Saturday 7.40pm. Score = 12'],
#   ['Richmond vs. Gold Coast at MCG, Sunday 1.10pm. Score = 28'],
#   ['St Kilda vs. Adelaide at Marvel Stadium, Sunday 3.20pm. Score = 25'],
#   ['North Melbourne vs. Carlton at Marvel Stadium, Sunday 4.40pm. Score = 31']],
#  'Round 16': [['Geelong vs. Essendon at GMHBA Stadium, Thursday 7.50pm. Score = 11'],
#   ['Melbourne vs. St Kilda at MCG, Friday 7.50pm. Score = 11'],
#   ['Brisbane vs. North Melbourne at Gabba, Saturday 1.45pm. Score = 22'],
#   ['Gold Coast vs. Western Bulldogs at Metricon Stadium, Saturday 2.10pm. Score = 21'],
#   ['Hawthorn vs. Port Adelaide at MCG, Saturday 7.25pm. Score = 16'],
#   ['Carlton vs. Sydney at MCG, Saturday 7.40pm. Score = 19'],
#   ['Richmond vs. Fremantle at MCG, Sunday 1.10pm. Score = 23'],
#   ['Adelaide vs. GWS at Adelaide Oval, Sunday 3.20pm. Score = 22'],
#   ['Collingwood vs. West Coast at MCG, Sunday 4.40pm. Score = 26']],
#  'Round 17': [['GWS vs. Melbourne at GIANTS Stadium, Thursday 7.50pm. Score = 8'],
#   ['Sydney vs. Brisbane at SCG, Friday 7.50pm. Score = 10'],
#   ['St Kilda vs. Richmond at Marvel Stadium, Saturday 1.45pm. Score = 22'],
#   ['North Melbourne vs. Geelong at Marvel Stadium, Saturday 2.10pm. Score = 21'],
#   ['Western Bulldogs vs. Carlton at Marvel Stadium, Saturday 7.25pm. Score = 18'],
#   ['Port Adelaide vs. Collingwood at Adelaide Oval, Saturday 7.40pm. Score = 19'],
#   ['West Coast vs. Adelaide at Optus Stadium, Sunday 1.10pm. Score = 24'],
#   ['Essendon vs. Hawthorn at MCG, Sunday 3.20pm. Score = 22'],
#   ['Fremantle vs. Gold Coast at Optus Stadium, Sunday 4.40pm. Score = 27']]}
