# %%
import random

# %%
teams = ["Adelaide","Brisbane","Carlton","Collingwood","Essendon","Fremantle","Geelong","Gold Coast","GWS",
        "Hawthorn","Melbourne","North Melbourne","Port Adelaide","Richmond","St Kilda","Sydney",
         "West Coast","Bulldogs"]

random.shuffle(teams)

# %%
def basic_rr(teams):
    s = {}
    s_per_team = {}
    h_count_per_team = {}
    ha_per_team = {}
    
    #if odd n_teams
    if len(teams) % 2 == 1: 
        teams = teams + [None]
    
    n = len(teams)
    
    for team in teams:
        s_per_team[team] = []
        h_count_per_team[team] = 0
        ha_per_team[team] = []
        
    mid = n//2
    
    for i in range(n-1):
        round=[]
        for j in range(mid):
            t1 = teams[j]
            t2 = teams[n-1-j]
            
            round.append((t1 + " vs. " + t2))
            
            s_per_team[t1].append(t2)
            s_per_team[t2].append(t1)
            h_count_per_team[t1] += 1
            ha_per_team[t1].append("Home")
            ha_per_team[t2].append("Away")
                
        s["Round " + str(i+1)] = round
        
        teams.insert(1,teams.pop())
        
    s_per_team = dict(sorted(s_per_team.items(), key=lambda x: x[0].lower()))
    h_count_per_team = dict(sorted(h_count_per_team.items(), key=lambda x: x[0].lower()))
    ha_per_team = dict(sorted(ha_per_team.items(), key=lambda x: x[0].lower()))
    
    return s, s_per_team, h_count_per_team, ha_per_team

# %%
def round_robin_fair(teams):
    """ Create a schedule for the teams in the list and return it"""
    s = {}
    s_per_team = {}
    h_count_per_team = {}
    ha_per_team = {}
    
    if len(teams) % 2 == 1: teams = teams + [None]
    # manipulate map (array of indexes for list) instead of list itself
    # this takes advantage of even/odd indexes to determine home vs. away
    n = len(teams)
    
    for team in teams:
        s_per_team[team] = []
        h_count_per_team[team] = 0
        ha_per_team[team] = []
        
    map = list(range(n))
    mid = n // 2
    for i in range(n-1):
        l1 = map[:mid]
        l2 = map[mid:]
        l2.reverse()
        #print("Round",i)
        round = []
        
        for j in range(mid):
            t1 = teams[l1[j]]
            t2 = teams[l2[j]]
            if j == 0 and i % 2 == 1:
                # flip the first match only, every other round
                # (this is because the first match always involves the last player in the list)
                round.append((t2 + " vs. " + t1))
                s_per_team[t2].append(t1)
                s_per_team[t1].append(t2)
                h_count_per_team[t2] += 1
                ha_per_team[t2].append("Home")
                ha_per_team[t1].append("Away")
            else:
                round.append((t1 + " vs. " + t2))
                s_per_team[t2].append(t1)
                s_per_team[t1].append(t2)
                h_count_per_team[t1] += 1
                ha_per_team[t1].append("Home")
                ha_per_team[t2].append("Away")
                
        s["Round " + str(i+1)] = round
        
        # rotate list by n/2, leaving last element at the end
        map = map[mid:-1] + map[:mid] + map[-1:]
        
    s_per_team = dict(sorted(s_per_team.items(), key=lambda x: x[0].lower()))
    h_count_per_team = dict(sorted(h_count_per_team.items(), key=lambda x: x[0].lower()))
    ha_per_team = dict(sorted(ha_per_team.items(), key=lambda x: x[0].lower()))
    
    return s, s_per_team, h_count_per_team, ha_per_team

# %%
basic_sched, basic_per_team, basic_hcpt, basic_hapt = basic_rr(teams)

# %%
basic_sched
# Out:
# {'Round 1': ['Adelaide vs. Bulldogs',
#   'Brisbane vs. West Coast',
#   'Carlton vs. Sydney',
#   'Collingwood vs. St Kilda',
#   'Essendon vs. Richmond',
#   'Fremantle vs. Port Adelaide',
#   'Geelong vs. North Melbourne',
#   'Gold Coast vs. Melbourne',
#   'GWS vs. Hawthorn'],
#  'Round 2': ['Adelaide vs. West Coast',
#   'Bulldogs vs. Sydney',
#   'Brisbane vs. St Kilda',
#   'Carlton vs. Richmond',
#   'Collingwood vs. Port Adelaide',
#   'Essendon vs. North Melbourne',
#   'Fremantle vs. Melbourne',
#   'Geelong vs. Hawthorn',
#   'Gold Coast vs. GWS'],
#  'Round 3': ['Adelaide vs. Sydney',
#   'West Coast vs. St Kilda',
#   'Bulldogs vs. Richmond',
#   'Brisbane vs. Port Adelaide',
#   'Carlton vs. North Melbourne',
#   'Collingwood vs. Melbourne',
#   'Essendon vs. Hawthorn',
#   'Fremantle vs. GWS',
#   'Geelong vs. Gold Coast'],
#  'Round 4': ['Adelaide vs. St Kilda',
#   'Sydney vs. Richmond',
#   'West Coast vs. Port Adelaide',
#   'Bulldogs vs. North Melbourne',
#   'Brisbane vs. Melbourne',
#   'Carlton vs. Hawthorn',
#   'Collingwood vs. GWS',
#   'Essendon vs. Gold Coast',
#   'Fremantle vs. Geelong'],
#  'Round 5': ['Adelaide vs. Richmond',
#   'St Kilda vs. Port Adelaide',
#   'Sydney vs. North Melbourne',
#   'West Coast vs. Melbourne',
#   'Bulldogs vs. Hawthorn',
#   'Brisbane vs. GWS',
#   'Carlton vs. Gold Coast',
#   'Collingwood vs. Geelong',
#   'Essendon vs. Fremantle'],
#  'Round 6': ['Adelaide vs. Port Adelaide',
#   'Richmond vs. North Melbourne',
#   'St Kilda vs. Melbourne',
#   'Sydney vs. Hawthorn',
#   'West Coast vs. GWS',
#   'Bulldogs vs. Gold Coast',
#   'Brisbane vs. Geelong',
#   'Carlton vs. Fremantle',
#   'Collingwood vs. Essendon'],
#  'Round 7': ['Adelaide vs. North Melbourne',
#   'Port Adelaide vs. Melbourne',
#   'Richmond vs. Hawthorn',
#   'St Kilda vs. GWS',
#   'Sydney vs. Gold Coast',
#   'West Coast vs. Geelong',
#   'Bulldogs vs. Fremantle',
#   'Brisbane vs. Essendon',
#   'Carlton vs. Collingwood'],
#  'Round 8': ['Adelaide vs. Melbourne',
#   'North Melbourne vs. Hawthorn',
#   'Port Adelaide vs. GWS',
#   'Richmond vs. Gold Coast',
#   'St Kilda vs. Geelong',
#   'Sydney vs. Fremantle',
#   'West Coast vs. Essendon',
#   'Bulldogs vs. Collingwood',
#   'Brisbane vs. Carlton'],
#  'Round 9': ['Adelaide vs. Hawthorn',
#   'Melbourne vs. GWS',
#   'North Melbourne vs. Gold Coast',
#   'Port Adelaide vs. Geelong',
#   'Richmond vs. Fremantle',
#   'St Kilda vs. Essendon',
#   'Sydney vs. Collingwood',
#   'West Coast vs. Carlton',
#   'Bulldogs vs. Brisbane'],
#  'Round 10': ['Adelaide vs. GWS',
#   'Hawthorn vs. Gold Coast',
#   'Melbourne vs. Geelong',
#   'North Melbourne vs. Fremantle',
#   'Port Adelaide vs. Essendon',
#   'Richmond vs. Collingwood',
#   'St Kilda vs. Carlton',
#   'Sydney vs. Brisbane',
#   'West Coast vs. Bulldogs'],
#  'Round 11': ['Adelaide vs. Gold Coast',
#   'GWS vs. Geelong',
#   'Hawthorn vs. Fremantle',
#   'Melbourne vs. Essendon',
#   'North Melbourne vs. Collingwood',
#   'Port Adelaide vs. Carlton',
#   'Richmond vs. Brisbane',
#   'St Kilda vs. Bulldogs',
#   'Sydney vs. West Coast'],
#  'Round 12': ['Adelaide vs. Geelong',
#   'Gold Coast vs. Fremantle',
#   'GWS vs. Essendon',
#   'Hawthorn vs. Collingwood',
#   'Melbourne vs. Carlton',
#   'North Melbourne vs. Brisbane',
#   'Port Adelaide vs. Bulldogs',
#   'Richmond vs. West Coast',
#   'St Kilda vs. Sydney'],
#  'Round 13': ['Adelaide vs. Fremantle',
#   'Geelong vs. Essendon',
#   'Gold Coast vs. Collingwood',
#   'GWS vs. Carlton',
#   'Hawthorn vs. Brisbane',
#   'Melbourne vs. Bulldogs',
#   'North Melbourne vs. West Coast',
#   'Port Adelaide vs. Sydney',
#   'Richmond vs. St Kilda'],
#  'Round 14': ['Adelaide vs. Essendon',
#   'Fremantle vs. Collingwood',
#   'Geelong vs. Carlton',
#   'Gold Coast vs. Brisbane',
#   'GWS vs. Bulldogs',
#   'Hawthorn vs. West Coast',
#   'Melbourne vs. Sydney',
#   'North Melbourne vs. St Kilda',
#   'Port Adelaide vs. Richmond'],
#  'Round 15': ['Adelaide vs. Collingwood',
#   'Essendon vs. Carlton',
#   'Fremantle vs. Brisbane',
#   'Geelong vs. Bulldogs',
#   'Gold Coast vs. West Coast',
#   'GWS vs. Sydney',
#   'Hawthorn vs. St Kilda',
#   'Melbourne vs. Richmond',
#   'North Melbourne vs. Port Adelaide'],
#  'Round 16': ['Adelaide vs. Carlton',
#   'Collingwood vs. Brisbane',
#   'Essendon vs. Bulldogs',
#   'Fremantle vs. West Coast',
#   'Geelong vs. Sydney',
#   'Gold Coast vs. St Kilda',
#   'GWS vs. Richmond',
#   'Hawthorn vs. Port Adelaide',
#   'Melbourne vs. North Melbourne'],
#  'Round 17': ['Adelaide vs. Brisbane',
#   'Carlton vs. Bulldogs',
#   'Collingwood vs. West Coast',
#   'Essendon vs. Sydney',
#   'Fremantle vs. St Kilda',
#   'Geelong vs. Richmond',
#   'Gold Coast vs. Port Adelaide',
#   'GWS vs. North Melbourne',
#   'Hawthorn vs. Melbourne']}

# %%
basic_hapt
#note no HA-fair recurrence, lots of home and away games in a row, first team is biased all home
# Out:
# {'Adelaide': ['Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home'],
#  'Brisbane': ['Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away'],
#  'Bulldogs': ['Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away'],
#  'Carlton': ['Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home'],
#  'Collingwood': ['Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home'],
#  'Essendon': ['Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home'],
#  'Fremantle': ['Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home'],
#  'Geelong': ['Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home'],
#  'Gold Coast': ['Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home'],
#  'GWS': ['Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home'],
#  'Hawthorn': ['Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home'],
#  'Melbourne': ['Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away'],
#  'North Melbourne': ['Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away'],
#  'Port Adelaide': ['Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away'],
#  'Richmond': ['Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away'],
#  'St Kilda': ['Away',
#   'Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away'],
#  'Sydney': ['Away',
#   'Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away'],
#  'West Coast': ['Away',
#   'Away',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Home',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away',
#   'Away']}

# %%
sched, per_team, hcpt, hapt = round_robin_fair(teams)

# %%
sched
# Out:
# {'Round 1': ['Hawthorn vs. Essendon',
#   'North Melbourne vs. Melbourne',
#   'West Coast vs. Adelaide',
#   'Collingwood vs. Brisbane',
#   'Bulldogs vs. Carlton',
#   'Fremantle vs. Richmond',
#   'Sydney vs. Gold Coast',
#   'GWS vs. Port Adelaide',
#   'Geelong vs. St Kilda'],
#  'Round 2': ['Essendon vs. St Kilda',
#   'Port Adelaide vs. Geelong',
#   'Gold Coast vs. GWS',
#   'Richmond vs. Sydney',
#   'Carlton vs. Fremantle',
#   'Brisbane vs. Bulldogs',
#   'Adelaide vs. Collingwood',
#   'Melbourne vs. West Coast',
#   'Hawthorn vs. North Melbourne'],
#  'Round 3': ['North Melbourne vs. Essendon',
#   'West Coast vs. Hawthorn',
#   'Collingwood vs. Melbourne',
#   'Bulldogs vs. Adelaide',
#   'Fremantle vs. Brisbane',
#   'Sydney vs. Carlton',
#   'GWS vs. Richmond',
#   'Geelong vs. Gold Coast',
#   'St Kilda vs. Port Adelaide'],
#  'Round 4': ['Essendon vs. Port Adelaide',
#   'Gold Coast vs. St Kilda',
#   'Richmond vs. Geelong',
#   'Carlton vs. GWS',
#   'Brisbane vs. Sydney',
#   'Adelaide vs. Fremantle',
#   'Melbourne vs. Bulldogs',
#   'Hawthorn vs. Collingwood',
#   'North Melbourne vs. West Coast'],
#  'Round 5': ['West Coast vs. Essendon',
#   'Collingwood vs. North Melbourne',
#   'Bulldogs vs. Hawthorn',
#   'Fremantle vs. Melbourne',
#   'Sydney vs. Adelaide',
#   'GWS vs. Brisbane',
#   'Geelong vs. Carlton',
#   'St Kilda vs. Richmond',
#   'Port Adelaide vs. Gold Coast'],
#  'Round 6': ['Essendon vs. Gold Coast',
#   'Richmond vs. Port Adelaide',
#   'Carlton vs. St Kilda',
#   'Brisbane vs. Geelong',
#   'Adelaide vs. GWS',
#   'Melbourne vs. Sydney',
#   'Hawthorn vs. Fremantle',
#   'North Melbourne vs. Bulldogs',
#   'West Coast vs. Collingwood'],
#  'Round 7': ['Collingwood vs. Essendon',
#   'Bulldogs vs. West Coast',
#   'Fremantle vs. North Melbourne',
#   'Sydney vs. Hawthorn',
#   'GWS vs. Melbourne',
#   'Geelong vs. Adelaide',
#   'St Kilda vs. Brisbane',
#   'Port Adelaide vs. Carlton',
#   'Gold Coast vs. Richmond'],
#  'Round 8': ['Essendon vs. Richmond',
#   'Carlton vs. Gold Coast',
#   'Brisbane vs. Port Adelaide',
#   'Adelaide vs. St Kilda',
#   'Melbourne vs. Geelong',
#   'Hawthorn vs. GWS',
#   'North Melbourne vs. Sydney',
#   'West Coast vs. Fremantle',
#   'Collingwood vs. Bulldogs'],
#  'Round 9': ['Bulldogs vs. Essendon',
#   'Fremantle vs. Collingwood',
#   'Sydney vs. West Coast',
#   'GWS vs. North Melbourne',
#   'Geelong vs. Hawthorn',
#   'St Kilda vs. Melbourne',
#   'Port Adelaide vs. Adelaide',
#   'Gold Coast vs. Brisbane',
#   'Richmond vs. Carlton'],
#  'Round 10': ['Essendon vs. Carlton',
#   'Brisbane vs. Richmond',
#   'Adelaide vs. Gold Coast',
#   'Melbourne vs. Port Adelaide',
#   'Hawthorn vs. St Kilda',
#   'North Melbourne vs. Geelong',
#   'West Coast vs. GWS',
#   'Collingwood vs. Sydney',
#   'Bulldogs vs. Fremantle'],
#  'Round 11': ['Fremantle vs. Essendon',
#   'Sydney vs. Bulldogs',
#   'GWS vs. Collingwood',
#   'Geelong vs. West Coast',
#   'St Kilda vs. North Melbourne',
#   'Port Adelaide vs. Hawthorn',
#   'Gold Coast vs. Melbourne',
#   'Richmond vs. Adelaide',
#   'Carlton vs. Brisbane'],
#  'Round 12': ['Essendon vs. Brisbane',
#   'Adelaide vs. Carlton',
#   'Melbourne vs. Richmond',
#   'Hawthorn vs. Gold Coast',
#   'North Melbourne vs. Port Adelaide',
#   'West Coast vs. St Kilda',
#   'Collingwood vs. Geelong',
#   'Bulldogs vs. GWS',
#   'Fremantle vs. Sydney'],
#  'Round 13': ['Sydney vs. Essendon',
#   'GWS vs. Fremantle',
#   'Geelong vs. Bulldogs',
#   'St Kilda vs. Collingwood',
#   'Port Adelaide vs. West Coast',
#   'Gold Coast vs. North Melbourne',
#   'Richmond vs. Hawthorn',
#   'Carlton vs. Melbourne',
#   'Brisbane vs. Adelaide'],
#  'Round 14': ['Essendon vs. Adelaide',
#   'Melbourne vs. Brisbane',
#   'Hawthorn vs. Carlton',
#   'North Melbourne vs. Richmond',
#   'West Coast vs. Gold Coast',
#   'Collingwood vs. Port Adelaide',
#   'Bulldogs vs. St Kilda',
#   'Fremantle vs. Geelong',
#   'Sydney vs. GWS'],
#  'Round 15': ['GWS vs. Essendon',
#   'Geelong vs. Sydney',
#   'St Kilda vs. Fremantle',
#   'Port Adelaide vs. Bulldogs',
#   'Gold Coast vs. Collingwood',
#   'Richmond vs. West Coast',
#   'Carlton vs. North Melbourne',
#   'Brisbane vs. Hawthorn',
#   'Adelaide vs. Melbourne'],
#  'Round 16': ['Essendon vs. Melbourne',
#   'Hawthorn vs. Adelaide',
#   'North Melbourne vs. Brisbane',
#   'West Coast vs. Carlton',
#   'Collingwood vs. Richmond',
#   'Bulldogs vs. Gold Coast',
#   'Fremantle vs. Port Adelaide',
#   'Sydney vs. St Kilda',
#   'GWS vs. Geelong'],
#  'Round 17': ['Geelong vs. Essendon',
#   'St Kilda vs. GWS',
#   'Port Adelaide vs. Sydney',
#   'Gold Coast vs. Fremantle',
#   'Richmond vs. Bulldogs',
#   'Carlton vs. Collingwood',
#   'Brisbane vs. West Coast',
#   'Adelaide vs. North Melbourne',
#   'Melbourne vs. Hawthorn']}

# %%
#fair HA recurrence
hapt
# Out:
# {'Adelaide': ['Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Away',
#   'Home',
#   'Away',
#   'Home'],
#  'Brisbane': ['Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home'],
#  'Bulldogs': ['Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away'],
#  'Carlton': ['Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home'],
#  'Collingwood': ['Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away'],
#  'Essendon': ['Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away'],
#  'Fremantle': ['Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away'],
#  'Geelong': ['Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home'],
#  'Gold Coast': ['Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home'],
#  'GWS': ['Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Home',
#   'Away'],
#  'Hawthorn': ['Home',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away'],
#  'Melbourne': ['Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Away',
#   'Home'],
#  'North Melbourne': ['Home',
#   'Away',
#   'Home',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away'],
#  'Port Adelaide': ['Away',
#   'Home',
#   'Away',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home'],
#  'Richmond': ['Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home'],
#  'St Kilda': ['Away',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home'],
#  'Sydney': ['Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Home',
#   'Away',
#   'Home',
#   'Away'],
#  'West Coast': ['Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away',
#   'Home',
#   'Away']}
